# %% [markdown]
# # Four Automated Tools for Exploratory Data Analysis
# - DataPrep
# - Pandas Profiling
# - SweetViz
# - AutoViz
# - dtale
#
# **Autoviz in this notebook**
#
# ### Reference:
#    1. https://builtin.com/data-science/EDA-python
#    2. https://www.analyticsvidhya.com/blog/2021/04/top-python-libraries-to-automate-exploratory-data-analysis-in-2021/
#
# ### Reading Dataset

# %%
import pandas as pd
df = pd.read_csv("Travel.csv")
df
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0           Salaried  Female                       3                3.0
# 1           Salaried    Male                       3                4.0
# 2        Free Lancer    Male                       3                4.0
# 3           Salaried  Female                       2                3.0
# 4     Small Business    Male                       2                3.0
# ...              ...     ...                     ...                ...
# 4883  Small Business    Male                       3                5.0
# 4884        Salaried    Male                       4                5.0
# 4885        Salaried  Female                       4                4.0
# 4886  Small Business    Male                       3                4.0
# 4887        Salaried    Male                       4                4.0
#
#      ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0            Deluxe                    3.0        Single            1.0
# 1            Deluxe                    4.0      Divorced            2.0
# 2             Basic                    3.0        Single            7.0
# 3             Basic                    3.0      Divorced            2.0
# 4             Basic                    4.0      Divorced            1.0
# ...             ...                    ...           ...            ...
# 4883         Deluxe                    4.0     Unmarried            2.0
# 4884          Basic                    3.0        Single            3.0
# 4885       Standard                    4.0       Married            7.0
# 4886          Basic                    3.0        Single            3.0
# 4887          Basic                    4.0     Unmarried            3.0
#
#       Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 0            1                       2       1                       0.0
# 1            0                       3       1                       2.0
# 2            1                       3       0                       0.0
# 3            1                       5       1                       1.0
# 4            0                       5       1                       0.0
# ...        ...                     ...     ...                       ...
# 4883         1                       1       1                       1.0
# 4884         1                       3       1                       2.0
# 4885         0                       1       1                       3.0
# 4886         0                       5       0                       2.0
# 4887         1                       3       1                       2.0
#
#          Designation  MonthlyIncome
# 0            Manager        20993.0
# 1            Manager        20130.0
# 2          Executive        17090.0
# 3          Executive        17909.0
# 4          Executive        18468.0
# ...              ...            ...
# 4883         Manager        26576.0
# 4884       Executive        21212.0
# 4885  Senior Manager        31820.0
# 4886       Executive        20289.0
# 4887       Executive        24041.0
#
# [4888 rows x 20 columns]

# %% [markdown]
# # **4. AutoViz**

# %%
# pip install autoviz

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
df_av = AV.AutoViz('Travel.csv')
# Out:
# Shape of your Data Set loaded: (4888, 20)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# <style type="text/css">
# #T_cb648_row0_col0, #T_cb648_row0_col4, #T_cb648_row3_col2, #T_cb648_row3_col3, #T_cb648_row17_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cb648_row0_col1, #T_cb648_row0_col6, #T_cb648_row1_col1, #T_cb648_row1_col6, #T_cb648_row2_col1, #T_cb648_row2_col6, #T_cb648_row3_col1, #T_cb648_row3_col6, #T_cb648_row4_col1, #T_cb648_row4_col6, #T_cb648_row5_col1, #T_cb648_row5_col6, #T_cb648_row6_col1, #T_cb648_row6_col6, #T_cb648_row7_col1, #T_cb648_row7_col6, #T_cb648_row8_col1, #T_cb648_row8_col6, #T_cb648_row9_col1, #T_cb648_row9_col6, #T_cb648_row10_col1, #T_cb648_row10_col6, #T_cb648_row11_col1, #T_cb648_row11_col6, #T_cb648_row12_col1, #T_cb648_row12_col6, #T_cb648_row13_col1, #T_cb648_row13_col6, #T_cb648_row14_col1, #T_cb648_row14_col6, #T_cb648_row15_col1, #T_cb648_row15_col6, #T_cb648_row16_col1, #T_cb648_row16_col6, #T_cb648_row17_col1, #T_cb648_row17_col6, #T_cb648_row18_col1, #T_cb648_row18_col6, #T_cb648_row19_col1, #T_cb648_row19_col6 {
#   font-family: Segoe UI;
# }
# #T_cb648_row0_col2, #T_cb648_row0_col3, #T_cb648_row0_col5, #T_cb648_row1_col5, #T_cb648_row2_col5, #T_cb648_row3_col5, #T_cb648_row4_col0, #T_cb648_row4_col4, #T_cb648_row4_col5, #T_cb648_row5_col0, #T_cb648_row5_col4, #T_cb648_row5_col5, #T_cb648_row6_col0, #T_cb648_row6_col2, #T_cb648_row6_col3, #T_cb648_row6_col4, #T_cb648_row7_col0, #T_cb648_row7_col2, #T_cb648_row7_col3, #T_cb648_row7_col4, #T_cb648_row7_col5, #T_cb648_row8_col0, #T_cb648_row8_col2, #T_cb648_row8_col3, #T_cb648_row8_col4, #T_cb648_row9_col0, #T_cb648_row9_col2, #T_cb648_row9_col3, #T_cb648_row9_col4, #T_cb648_row9_col5, #T_cb648_row10_col0, #T_cb648_row10_col2, #T_cb648_row10_col3, #T_cb648_row10_col4, #T_cb648_row11_col0, #T_cb648_row11_col2, #T_cb648_row11_col3, #T_cb648_row11_col4, #T_cb648_row11_col5, #T_cb648_row12_col0, #T_cb648_row12_col4, #T_cb648_row12_col5, #T_cb648_row13_col0, #T_cb648_row13_col2, #T_cb648_row13_col3, #T_cb648_row13_col4, #T_cb648_row14_col0, #T_cb648_row14_col2, #T_cb648_row14_col3, #T_cb648_row14_col4, #T_cb648_row14_col5, #T_cb648_row15_col0, #T_cb648_row15_col4, #T_cb648_row15_col5, #T_cb648_row16_col0, #T_cb648_row16_col2, #T_cb648_row16_col3, #T_cb648_row16_col4, #T_cb648_row16_col5, #T_cb648_row17_col0, #T_cb648_row17_col4, #T_cb648_row18_col0, #T_cb648_row18_col2, #T_cb648_row18_col3, #T_cb648_row18_col4, #T_cb648_row18_col5, #T_cb648_row19_col0, #T_cb648_row19_col2, #T_cb648_row19_col3, #T_cb648_row19_col4, #T_cb648_row19_col5 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cb648_row1_col0, #T_cb648_row1_col4 {
#   background-color: #fa6849;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cb648_row1_col2, #T_cb648_row1_col3 {
#   background-color: #8a0812;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cb648_row2_col0, #T_cb648_row2_col4 {
#   background-color: #fff4ee;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cb648_row2_col2, #T_cb648_row2_col3 {
#   background-color: #980c13;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cb648_row3_col0, #T_cb648_row3_col4 {
#   background-color: #fff4ef;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cb648_row4_col2, #T_cb648_row4_col3 {
#   background-color: #f6553c;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cb648_row5_col2, #T_cb648_row5_col3 {
#   background-color: #fdd1be;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cb648_row6_col5, #T_cb648_row8_col5 {
#   background-color: #fdd5c4;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cb648_row10_col5 {
#   background-color: #fb7050;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cb648_row12_col2, #T_cb648_row12_col3 {
#   background-color: #fcb79c;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cb648_row13_col5 {
#   background-color: #fee3d7;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cb648_row15_col2, #T_cb648_row15_col3 {
#   background-color: #fee4d8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cb648_row17_col2, #T_cb648_row17_col3 {
#   background-color: #fee5d8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_cb648">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb648_level0_col0" class="col_heading level0 col0" >Nuniques</th>
#       <th id="T_cb648_level0_col1" class="col_heading level0 col1" >dtype</th>
#       <th id="T_cb648_level0_col2" class="col_heading level0 col2" >Nulls</th>
#       <th id="T_cb648_level0_col3" class="col_heading level0 col3" >Nullpercent</th>
#       <th id="T_cb648_level0_col4" class="col_heading level0 col4" >NuniquePercent</th>
#       <th id="T_cb648_level0_col5" class="col_heading level0 col5" >Value counts Min</th>
#       <th id="T_cb648_level0_col6" class="col_heading level0 col6" >Data cleaning improvement suggestions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb648_level0_row0" class="row_heading level0 row0" >CustomerID</th>
#       <td id="T_cb648_row0_col0" class="data row0 col0" >4888</td>
#       <td id="T_cb648_row0_col1" class="data row0 col1" >int64</td>
#       <td id="T_cb648_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_cb648_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_cb648_row0_col4" class="data row0 col4" >100.000000</td>
#       <td id="T_cb648_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_cb648_row0_col6" class="data row0 col6" >possible ID column: drop</td>
#     </tr>
#     <tr>
#       <th id="T_cb648_level0_row1" class="row_heading level0 row1" >MonthlyIncome</th>
#       <td id="T_cb648_row1_col0" class="data row1 col0" >2475</td>
#       <td id="T_cb648_row1_col1" class="data row1 col1" >float64</td>
#       <td id="T_cb648_row1_col2" class="data row1 col2" >233</td>
#       <td id="T_cb648_row1_col3" class="data row1 col3" >4.766776</td>
#       <td id="T_cb648_row1_col4" class="data row1 col4" >50.634206</td>
#       <td id="T_cb648_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_cb648_row1_col6" class="data row1 col6" >fill missing values, skewed column: cap or drop possible outliers</td>
#     </tr>
#     <tr>
#       <th id="T_cb648_level0_row2" class="row_heading level0 row2" >Age</th>
#       <td id="T_cb648_row2_col0" class="data row2 col0" >44</td>
#       <td id="T_cb648_row2_col1" class="data row2 col1" >float64</td>
#       <td id="T_cb648_row2_col2" class="data row2 col2" >226</td>
#       <td id="T_cb648_row2_col3" class="data row2 col3" >4.623568</td>
#       <td id="T_cb648_row2_col4" class="data row2 col4" >0.900164</td>
#       <td id="T_cb648_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_cb648_row2_col6" class="data row2 col6" >fill missing values</td>
#     </tr>
#     <tr>
#       <th id="T_cb648_level0_row3" class="row_heading level0 row3" >DurationOfPitch</th>
#       <td id="T_cb648_row3_col0" class="data row3 col0" >34</td>
#       <td id="T_cb648_row3_col1" class="data row3 col1" >float64</td>
#       <td id="T_cb648_row3_col2" class="data row3 col2" >251</td>
#       <td id="T_cb648_row3_col3" class="data row3 col3" >5.135025</td>
#       <td id="T_cb648_row3_col4" class="data row3 col4" >0.695581</td>
#       <td id="T_cb648_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_cb648_row3_col6" class="data row3 col6" >fill missing values, skewed column: cap or drop possible outliers</td>
#     </tr>
#     <tr>
#       <th id="T_cb648_level0_row4" class="row_heading level0 row4" >NumberOfTrips</th>
#       <td id="T_cb648_row4_col0" class="data row4 col0" >12</td>
#       <td id="T_cb648_row4_col1" class="data row4 col1" >float64</td>
#       <td id="T_cb648_row4_col2" class="data row4 col2" >140</td>
#       <td id="T_cb648_row4_col3" class="data row4 col3" >2.864157</td>
#       <td id="T_cb648_row4_col4" class="data row4 col4" >0.245499</td>
#       <td id="T_cb648_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_cb648_row4_col6" class="data row4 col6" >fill missing values, skewed column: cap or drop possible outliers</td>
#     </tr>
#     <tr>
#       <th id="T_cb648_level0_row5" class="row_heading level0 row5" >NumberOfFollowups</th>
#     20 Predictors classified...
#         1 variables removed since they were ID or low-information variables
#         List of variables removed: ['CustomerID']
# Number of All Scatter Plots = 28
# All Plots done
# Time to run AutoViz = 7 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
